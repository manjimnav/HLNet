# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Informer2020/
# !python -u main_informer.py --model informer --data ETTh1 --attn full --seq_len 168 --features S --train_epochs 10 --pred_len 72 --label_len 144
# Out:
# /content/drive/MyDrive/Informer2020
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl168_ll144_pl72_dm512_nh8_el3_dl2_df1024_atfull_ebfixed_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8401
# val 2809
# test 2809
# 	iters: 100, epoch: 1 | loss: 0.1658358
# 	speed: 3.0874s/iter; left time: 7783.3756s
# 	iters: 200, epoch: 1 | loss: 0.1008432
# 	speed: 3.1095s/iter; left time: 7528.0984s
# Epoch: 1, Steps: 262 | Train Loss: 0.2175947 Vali Loss: 0.2027357 Test Loss: 0.5393666
# Validation loss decreased (inf --> 0.202736).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.0948495
# 	speed: 6.9455s/iter; left time: 15689.8605s
# 	iters: 200, epoch: 2 | loss: 0.0762459
# 	speed: 3.1094s/iter; left time: 6713.2926s
# Epoch: 2, Steps: 262 | Train Loss: 0.1039654 Vali Loss: 0.2259755 Test Loss: 0.6290371
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0761866
# ...

# %%
# %cd /content/drive/MyDrive/HLInformer2020/
# !python -u main_informer.py --model informer --data ETTh1 --attn prob --attn full --seq_len 168 --features S --train_epochs 10 --pred_len 72 --label_len 144
# Out:
# /content/drive/MyDrive/HLInformer2020
# Use GPU: cuda:0
# >>>>>>>start training : informer_ETTh1_ftS_sl168_ll144_pl72_dm512_nh8_el3_dl2_df1024_atfull_ebfixed_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8401
# val 2809
# test 2809
# 	iters: 100, epoch: 1 | loss: 0.4303326
# 	speed: 3.5336s/iter; left time: 8908.3289s
# 	iters: 200, epoch: 1 | loss: 0.2608381
# 	speed: 3.5544s/iter; left time: 8605.2230s
# Epoch: 1, Steps: 262 | Train Loss: 0.3981043 Vali Loss: 0.2767846 Test Loss: 0.6236198
# Validation loss decreased (inf --> 0.276785).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.2120538
# 	speed: 7.9726s/iter; left time: 18010.1135s
# 	iters: 200, epoch: 2 | loss: 0.2087976
# 	speed: 3.5524s/iter; left time: 7669.6496s
# Epoch: 2, Steps: 262 | Train Loss: 0.2404374 Vali Loss: 0.3236658 Test Loss: 0.5479539
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.1875991
# ...
